# %% [markdown]
# Proyecto 1: Salarios de Trabajos de Ciencias de Datos
#
# Desarrollado por: Josué Jair Pelagio Monroy

# %% [markdown]
# ![salarios de trabajo.webp](data:image/webp;base64,...)

# %% [markdown]
# #“Salarios de trabajos de ciencia de datos”
#
#
# ## Índice
#
# ### [Introducción](#introducción)
#   [Base de Datos](#base-datos)
#     [Tarea](#task)
#
# ### [Preparación](#preparacion)
#    [Paquetes](#paquetes)
#    [Carga de Datos](#carga-datos)
#    [Comprensión de los Datos](#comprension-datos)
#
# ### [Análisis Exploratorio de Datos (EDA)](#eda)
#    [Análisis Univariado](#analisis-univariado)
#    [Distribución de Salarios por Año](#distribucion-salarios)
#    [Salarios Promedios por Países que Ofrecen Empleos](#salarios-paises)
#    [Gráfica Interactiva de Salarios por Título de Trabajo](#grafica-salarios-titulo)
#   [Análisis Bivariado](#analisis-bivariado)
#     [Salarios por Título de Trabajo](#salarios-titulo)
#    [Matriz de Correlación de Pearson](#matriz-correlacion)
#
#
# ### [Conclusiones Generales](#conclusiones-generales)
#
# ### [Conclusiones del EDA](#conclusiones-eda)
#
# #####[Referencias y Links de Apoyo](#referencias)

# %% [markdown]
# # <a name="introducción"></a> Introducción:
#
# El objetivo de este proyecto es realizar un análisis exploratorio de datos (EDA) sobre la base de datos de salarios de trabajos en ciencia de datos, utilizando técnicas de análisis univariado y bivariado, así como visualizaciones proporcionadas por Pandas. En resumen, entender las posibles ganancias y la expectativa salarial alrededor del mundo de un científico de datos.
#
# ## <a name="descripcion-columnas"></a> 1. Diccionario:
#
#
# | Columna           | Descripción                                                       |
# |-------------------|-------------------------------------------------------------------|
# | work_year         | Año de trabajo                                                    |
# | experience_level  | Nivel de experiencia del empleado en el puesto                    |
# | employment_type   | Tipo de empleo                                                    |
# | job_title         | Título del trabajo                                                |
# | salary            | Salario bruto anual                                               |
# | salary_currency   | Moneda del salario                                                |
# | salary_in_usd     | Salario convertido a USD                                          |
# | employee_residence| Residencia del empleado                                           |
# | remote_ratio      | Porcentaje de trabajo remoto                                      |
# | company_location  | Ubicación de la empresa                                           |
# | company_size      | Tamaño de la empresa                                              |
# > Agregar bloque entrecomillado

# %% [markdown]
# ## <a name="base-datos"></a>  Base de datos analizada
# base de datos:
# https://drive.google.com/file/d/1xEGMqIMDPZK-7yte8u3vnYyKB--J-x0s/view?usp=drive_link

# %% [markdown]
# ## <a name="task"></a> Tarea
# Crear Un notebook donde se hará un EDA básico que principalmente entenderá el principio del análisis univariado, así como, la carga de datos desde Pandas (cuya herramienta en Data Science es la más importante). Al finalizar construirá un documento con dichos resultados.

# %% [markdown]
# # <a name="preparacion"></a>  Preparación

# %% [markdown]
# <a name="paquetes"></a>  Paquetes
# En esta sección, cargaremos las librerías necesarias para realizar el análisis de datos. A continuación se detalla el propósito de cada una de ellas:
#
# - **NumPy**: Es una librería para el cálculo numérico en Python. Es especialmente útil para trabajar con arreglos y realizar operaciones matemáticas y lógicas de forma eficiente.
# - **Pandas**: Es una librería de análisis de datos que proporciona estructuras de datos y herramientas para manipular tablas y series temporales. Es fundamental para la manipulación y análisis de datos.
# - **Matplotlib**: Es una librería de visualización de datos en Python. Se utiliza para crear gráficos estáticos, animados e interactivos.
# - **Seaborn**: Es una librería de visualización de datos basada en Matplotlib. Proporciona una interfaz de alto nivel para dibujar gráficos estadísticos atractivos y fáciles de interpretar.

# %%
import numpy as np
import pandas as pd
import os
import csv
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# <a name="carga-datos"></a>  Carga de Datos
# cargaremos los datos desde un archivo CSV.

# %%
datos = pd.read_csv('/content/ds_salaries.csv') #Es necesario cambiar la ruta del archivo .cvs
datos
# Out:
#      Unnamed: 0  work_year experience_level employment_type  \
# 0             0       2020               MI              FT
# 1             1       2020               SE              FT
# 2             2       2020               SE              FT
# 3             3       2020               MI              FT
# 4             4       2020               SE              FT
# ..          ...        ...              ...             ...
# 602         602       2022               SE              FT
# 603         603       2022               SE              FT
# 604         604       2022               SE              FT
# 605         605       2022               SE              FT
# 606         606       2022               MI              FT
#
#                       job_title  salary salary_currency  salary_in_usd  \
# 0                Data Scientist   70000             EUR          79833
# 1    Machine Learning Scientist  260000             USD         260000
# 2             Big Data Engineer   85000             GBP         109024
# 3          Product Data Analyst   20000             USD          20000
# 4     Machine Learning Engineer  150000             USD         150000
# ..                          ...     ...             ...            ...
# 602               Data Engineer  154000             USD         154000
# 603               Data Engineer  126000             USD         126000
# 604                Data Analyst  129000             USD         129000
# 605                Data Analyst  150000             USD         150000
# 606                AI Scientist  200000             USD         200000
#
#     employee_residence  remote_ratio company_location company_size
# 0                   DE             0               DE            L
# 1                   JP             0               JP            S
# 2                   GB            50               GB            M
# 3                   HN             0               HN            S
# 4                   US            50               US            L
# ..                 ...           ...              ...          ...
# 602                 US           100               US            M
# 603                 US           100               US            M
# 604                 US             0               US            M
# 605                 US           100               US            M
# 606                 IN           100               US            L
#
# [607 rows x 12 columns]

# %%
print("La forma de los datos es: ", datos.shape)
# Out:
# La forma de los datos es:  (607, 11)

# %% [markdown]
# <a name="comprension-datos"></a> Comprensión de los datos
# En esta sección, exploraremos la estructura y contenido de los datos para entender mejor lo que estamos analizando.

# %%
datos.head()
# Out:
#    Unnamed: 0  work_year experience_level employment_type  \
# 0           0       2020               MI              FT
# 1           1       2020               SE              FT
# 2           2       2020               SE              FT
# 3           3       2020               MI              FT
# 4           4       2020               SE              FT
#
#                     job_title  salary salary_currency  salary_in_usd  \
# 0              Data Scientist   70000             EUR          79833
# 1  Machine Learning Scientist  260000             USD         260000
# 2           Big Data Engineer   85000             GBP         109024
# 3        Product Data Analyst   20000             USD          20000
# 4   Machine Learning Engineer  150000             USD         150000
#
#   employee_residence  remote_ratio company_location company_size
# 0                 DE             0               DE            L
# 1                 JP             0               JP            S
# 2                 GB            50               GB            M
# 3                 HN             0               HN            S
# 4                 US            50               US            L

# %%
if 'Unnamed: 0' in datos.columns:
    datos = datos.drop(columns=['Unnamed: 0'])
    print("Columna 'Unnamed: 0' eliminada.")
else:
    print("Columna 'Unnamed: 0' no encontrada en el DataFrame.")

# Verificar que la columna ha sido eliminada
print(datos.head())
# Out:
# Columna 'Unnamed: 0' no encontrada en el DataFrame.
#    work_year experience_level employment_type                   job_title  \
# 0       2020               MI              FT              Data Scientist
# 1       2020               SE              FT  Machine Learning Scientist
# 2       2020               SE              FT           Big Data Engineer
# 3       2020               MI              FT        Product Data Analyst
# 4       2020               SE              FT   Machine Learning Engineer
#
#    salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0   70000             EUR          79833                 DE             0
# 1  260000             USD         260000                 JP             0
# 2   85000             GBP         109024                 GB            50
# 3   20000             USD          20000                 HN             0
# 4  150000             USD         150000                 US            50
#
#   company_location company_size
# 0               DE            L
# 1               JP            S
# 2               GB            M
# 3               HN            S
# 4               US            L

# %%
print("La forma de los datos es: ", datos.shape)
# Out:
# La forma de los datos es:  (607, 11)

# %%
datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 607 entries, 0 to 606
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          607 non-null    int64
#  1   work_year           607 non-null    int64
#  2   experience_level    607 non-null    object
#  3   employment_type     607 non-null    object
#  4   job_title           607 non-null    object
#  5   salary              607 non-null    int64
#  6   salary_currency     607 non-null    object
#  7   salary_in_usd       607 non-null    int64
#  8   employee_residence  607 non-null    object
#  9   remote_ratio        607 non-null    int64
#  10  company_location    607 non-null    object
#  11  company_size        607 non-null    object
# dtypes: int64(5), object(7)
# memory usage: 57.0+ KB

# %%
datos.describe(include='all')
# Out:
#         Unnamed: 0    work_year experience_level employment_type  \
# count   607.000000   607.000000              607             607
# unique         NaN          NaN                4               4
# top            NaN          NaN               SE              FT
# freq           NaN          NaN              280             588
# mean    303.000000  2021.405272              NaN             NaN
# std     175.370085     0.692133              NaN             NaN
# min       0.000000  2020.000000              NaN             NaN
# 25%     151.500000  2021.000000              NaN             NaN
# 50%     303.000000  2022.000000              NaN             NaN
# 75%     454.500000  2022.000000              NaN             NaN
# max     606.000000  2022.000000              NaN             NaN
#
#              job_title        salary salary_currency  salary_in_usd  \
# count              607  6.070000e+02             607     607.000000
# unique              50           NaN              17            NaN
# top     Data Scientist           NaN             USD            NaN
# freq               143           NaN             398            NaN
# mean               NaN  3.240001e+05             NaN  112297.869852
# std                NaN  1.544357e+06             NaN   70957.259411
# min                NaN  4.000000e+03             NaN    2859.000000
# 25%                NaN  7.000000e+04             NaN   62726.000000
# 50%                NaN  1.150000e+05             NaN  101570.000000
# 75%                NaN  1.650000e+05             NaN  150000.000000
# max                NaN  3.040000e+07             NaN  600000.000000
#
#        employee_residence  remote_ratio company_location company_size
# count                 607     607.00000              607          607
# unique                 57           NaN               50            3
# top                    US           NaN               US            M
# freq                  332           NaN              355          326
# mean                  NaN      70.92257              NaN          NaN
# std                   NaN      40.70913              NaN          NaN
# min                   NaN       0.00000              NaN          NaN
# 25%                   NaN      50.00000              NaN          NaN
# 50%                   NaN     100.00000              NaN          NaN
# 75%                   NaN     100.00000              NaN          NaN
# max                   NaN     100.00000              NaN          NaN

# %%
datos.value_counts()
# Out:
# work_year  experience_level  employment_type  job_title           salary  salary_currency  salary_in_usd  employee_residence  remote_ratio  company_location  company_size
# 2022       SE                FT               Data Scientist      140000  USD              140000         US                  100           US                M               6
#                                               Data Analyst        90320   USD              90320          US                  100           US                M               5
#                                               Data Scientist      210000  USD              210000         US                  100           US                M               4
#                                               Data Analyst        112900  USD              112900         US                  100           US                M               4
#                                               Data Scientist      123000  USD              123000         US                  100           US                M               3
#                                                                                                                                                                              ..
# 2021       MI                FT               Data Scientist      75000   EUR              88654          DE                  50            DE                L               1
#                                                                   73000   USD              73000          US                  0             US                L               1
#                                                                   69600   BRL              12901          BR                  0             BR                S               1
#                                                                   58000   MXN              2859           MX                  0             MX                S               1
# 2022       SE                FT               Research Scientist  144000  USD              144000         US                  50            US                L               1
# Name: count, Length: 565, dtype: int64

# %%
datos['job_title'] .unique()
# Out:
# array(['Data Scientist', 'Machine Learning Scientist',
#        'Big Data Engineer', 'Product Data Analyst',
#        'Machine Learning Engineer', 'Data Analyst', 'Lead Data Scientist',
#        'Business Data Analyst', 'Lead Data Engineer', 'Lead Data Analyst',
#        'Data Engineer', 'Data Science Consultant', 'BI Data Analyst',
#        'Director of Data Science', 'Research Scientist',
#        'Machine Learning Manager', 'Data Engineering Manager',
#        'Machine Learning Infrastructure Engineer', 'ML Engineer',
#        'AI Scientist', 'Computer Vision Engineer',
#        'Principal Data Scientist', 'Data Science Manager', 'Head of Data',
#        '3D Computer Vision Researcher', 'Data Analytics Engineer',
#        'Applied Data Scientist', 'Marketing Data Analyst',
#        'Cloud Data Engineer', 'Financial Data Analyst',
#        'Computer Vision Software Engineer',
#        'Director of Data Engineering', 'Data Science Engineer',
#        'Principal Data Engineer', 'Machine Learning Developer',
#        'Applied Machine Learning Scientist', 'Data Analytics Manager',
#        'Head of Data Science', 'Data Specialist', 'Data Architect',
#        'Finance Data Analyst', 'Principal Data Analyst',
#        'Big Data Architect', 'Staff Data Scientist', 'Analytics Engineer',
#        'ETL Developer', 'Head of Machine Learning', 'NLP Engineer',
#        'Lead Machine Learning Engineer', 'Data Analytics Lead'],
#       dtype=object)

# %% [markdown]
# ### <a name="eda"></a>  Análisis Exploratorio de Datos (EDA)
#
# ## <a name="analisis-univariado"></a>  Análisis Univariado
#
# El análisis univariado se centra en una sola variable a la vez. Este tipo de análisis se utiliza para entender la distribución, tendencia central y dispersión de la variable. A continuación, se presentan algunas visualizaciones para el análisis univariado.

# %% [markdown]
# exploracion de los datos por medio de visualizaciones
#
# salarios por años

# %%
if 'Unnamed: 0' in datos.columns:
    datos = datos.drop(columns=['Unnamed: 0'])
    print("Columna 'Unnamed: 0' eliminada.")
else:
    print("Columna 'Unnamed: 0' no encontrada en el DataFrame.")

print(datos.head())
# Out:
# Columna 'Unnamed: 0' no encontrada en el DataFrame.
#    work_year experience_level employment_type                   job_title  \
# 0       2020               MI              FT              Data Scientist
# 1       2020               SE              FT  Machine Learning Scientist
# 2       2020               SE              FT           Big Data Engineer
# 3       2020               MI              FT        Product Data Analyst
# 4       2020               SE              FT   Machine Learning Engineer
#
#    salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0   70000             EUR          79833                 DE             0
# 1  260000             USD         260000                 JP             0
# 2   85000             GBP         109024                 GB            50
# 3   20000             USD          20000                 HN             0
# 4  150000             USD         150000                 US            50
#
#   company_location company_size
# 0               DE            L
# 1               JP            S
# 2               GB            M
# 3               HN            S
# 4               US            L

# %% [markdown]
# # <a name="distribucion-salarios"></a> Distribución de Salarios por año
#
# > Añadir blockquote

# %%
ax = sns.barplot(data=datos,x='work_year', y='salary_in_usd')
ax.bar_label(ax.containers[0])
plt.show()

# %% [markdown]
# # <a name="salarios-paises"></a> Salarios promedios por países que ofrecen empleos

# %% [markdown]
# salarios promedios por países que ofrecen empleos

# %%
salario_pais = datos.groupby(by='company_location')['salary_in_usd'].mean().reset_index().sort_values(by='salary_in_usd', ascending=False)
salario_pais['salary_in_usd'] = salario_pais['salary_in_usd']/1000
COND = salario_pais ['salary_in_usd'] > 99.84
salario_pais = salario_pais[COND]

# %%
ax = sns.barplot(data=salario_pais,y='company_location', x='salary_in_usd', palette= 'rocket')
ax.bar_label(ax.containers[0])
ax.set_xlabel('salarios en miles de dolares')
plt.show()
# Out:
# <ipython-input-19-ff9946116006>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(data=salario_pais,y='company_location', x='salary_in_usd', palette= 'rocket')

# %% [markdown]
#  Gráfica Interactiva de Salarios por Título de Trabajo
# <a name="grafica-salarios-titulo"></a>

# %%
mean_sal_jobtitle = datos.groupby('job_title')['salary_in_usd'].mean().round(2).sort_values(ascending = False)
mean_sal_jobtitle
# Out:
# job_title
# Data Analytics Lead                         405000.00
# Principal Data Engineer                     328333.33
# Financial Data Analyst                      275000.00
# Principal Data Scientist                    215242.43
# Director of Data Science                    195074.00
# Data Architect                              177873.91
# Applied Data Scientist                      175655.00
# Analytics Engineer                          175000.00
# Data Specialist                             165000.00
# Head of Data                                160162.60
# Machine Learning Scientist                  158412.50
# Data Science Manager                        158328.50
# Director of Data Engineering                156738.00
# Head of Data Science                        146718.75
# Applied Machine Learning Scientist          142068.75
# Lead Data Engineer                          139724.50
# Data Analytics Manager                      127134.29
# Cloud Data Engineer                         124647.00
# Data Engineering Manager                    123227.20
# Principal Data Analyst                      122500.00
# ML Engineer                                 117504.00
# Machine Learning Manager                    117104.00
# Lead Data Scientist                         115190.00
# Data Engineer                               112725.00
# Research Scientist                          109019.50
# Data Scientist                              108187.83
# Computer Vision Software Engineer           105248.67
# Staff Data Scientist                        105000.00
# Machine Learning Engineer                   104880.15
# Machine Learning Infrastructure Engineer    101145.00
# Big Data Architect                           99703.00
# Data Analyst                                 92893.06
# Lead Data Analyst                            92203.00
# Marketing Data Analyst                       88654.00
# Lead Machine Learning Engineer               87932.00
# Machine Learning Developer                   85860.67
# Head of Machine Learning                     79039.00
# Business Data Analyst                        76691.20
# Data Science Engineer                        75803.33
# BI Data Analyst                              74755.17
# Data Science Consultant                      69420.71
# AI Scientist                                 66135.57
# Data Analytics Engineer                      64799.25
# Finance Data Analyst                         61896.00
# ETL Developer                                54957.00
# Big Data Engineer                            51974.00
# Computer Vision Engineer                     44419.33
# NLP Engineer                                 37236.00
# Product Data Analyst                         13036.00
# 3D Computer Vision Researcher                 5409.00
# Name: salary_in_usd, dtype: float64

# %%
fig = px.bar(mean_sal_jobtitle, x=mean_sal_jobtitle.index, y=mean_sal_jobtitle.values,
             color=mean_sal_jobtitle.index, text=mean_sal_jobtitle.values, title='Salarios por especilidad' )
fig.update_traces(width=0.4)
fig.update_layout(
    xaxis_title="Especialidad",
    yaxis_title="Salario en dolares",
    font = dict(size=17))
fig.show()

datos.groupby('job_title').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right']].set_visible(False)
plt.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="8f3ac3da-e8d2-4a5b-a18a-b1c4744341d1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8f3ac3da-e8d2-4a5b-a18a-b1c4744341d1")) {                    Plotly.newPlot(                        "8f3ac3da-e8d2-4a5b-a18a-b1c4744341d1",                        [{"alignmentgroup":"True","hovertemplate":"job_title=%{x}\u003cbr\u003ey=%{y}\u003cbr\u003etext=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Data Analytics Lead","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Data Analytics Lead","offsetgroup":"Data Analytics Lead","orientation":"v","showlegend":true,"text":[405000.0],"textposition":"auto","x":["Data Analytics Lead"],"xaxis":"x","y":[405000.0],"yaxis":"y","type":"bar","width":0.4},{"alignmentgroup":"True","hovertemplate":"job_title=%{x}\u003cbr\u003ey=%{y}\u003cbr\u003etext=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Principal Data Engineer","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Principal Data Engineer","offsetgroup":"Principal Data Engineer","orientation":"v","showlegend":true,"text":[328333.33],"textposition":"auto","x":["Principal Data Engineer"],"xaxis":"x","y":[328333.33],"yaxis":"y","type":"bar","width":0.4},{"alignmentgroup":"True","hovertemplate":"job_title=%{x}\u003cbr\u003ey=%{y}\u003cbr\u003etext=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Financial Data Analyst","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Financial Data Analyst","offsetgroup":"Financial Data Analyst","orientation":"v","showlegend":true,"text":[275000.0],"textposition":"auto","x":["Financial Data Analyst"],"xaxis":"x","y":[275000.0],"yaxis":"y","type":"bar","width":0.4},{"alignmentgroup":"True","hovertemplate":"job_title=%{x}\u003cbr\u003ey=%{y}\u003cbr\u003etext=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Principal Data Scientist","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Principal Data Scientist","offsetgroup":"Principal Data Scientist","orientation":"v","showlegend":true,"text":[215242.43],"textposition":"auto","x":["Principal Data Scientist"],"xaxis":"x","y":[215242.43],"yaxis":"y","type":"bar","width":0.4},{"alignmentgroup":"True","hovertemplate":"job_title=%{x}\u003cbr\u003ey=%{y}\u003cbr\u003etext=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Director of Data Science","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Director of Data Science","offsetgroup":"Director of Data Science","orientation":"v","showlegend":true,"text":[195074.0],"textposition":"auto","x":["Director of Data Science"],"xaxis":"x","y":[195074.0],"yaxis":"y","type":"bar","width":0.4},{"alignmentgroup":"True","hovertemplate":"job_title=%{x}\u003cbr\u003ey=%{y}\u003cbr\u003etext=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Data Architect","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Data Architect","offsetgroup":"Data Architect","orientation":"v","showlegend":true,"text":[177873.91],"textposition":"auto","x":["Data Architect"],"xaxis":"x","y":[177873.91],"yaxis":"y","type":"bar","width":0.4},{"alignmentgroup":"True","hovertemplate":"job_title=%{x}\u003cbr\u003ey=%{y}\u003cbr\u003etext=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Applied Data Scientist","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Applied Data Scientist","offsetgroup":"Applied Data Scientist","orientation":"v","showlegend":true,"text":[175655.0],"textposition":"auto","x":["Applied Data Scientist"],"xaxis":"x","y":[175655.0],"yaxis":"y","type":"bar","width":0.4},{"alignmentgroup":"True","hovertemplate":"job_title=%{x}\u003cbr\u003ey=%{y}\u003cbr\u003etext=%{text}\u003c ...

# %% [markdown]
# ## <a name="analisis-bivariado"></a> Análisis Bivariado
#
# El análisis bivariado se utiliza para entender la relación entre dos variables. Este tipo de análisis puede revelar correlaciones y patrones de comportamiento entre las variables. A continuación, se presentan algunas visualizaciones para el análisis bivariado.

# %% [markdown]
# # <a name="salarios-titulo"></a> Salarios por Título de Trabajo

# %%
plt.figure(figsize=(12, 8))
sns.boxplot(x='job_title', y='salary_in_usd', data=datos)
plt.title('Salarios por Título de Trabajo')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # <a name="matriz-correlacion"></a>  Matriz de Correlación de Pearson

# %%
numerical_df = datos.select_dtypes(include=['number'])

corr_matrix = numerical_df.corr(method='pearson')

print(corr_matrix)

plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Matriz de Correlación de Pearson')
plt.show()
# Out:
#                work_year    salary  salary_in_usd  remote_ratio
# work_year       1.000000 -0.087577       0.170493      0.076314
# salary         -0.087577  1.000000      -0.083906     -0.014608
# salary_in_usd   0.170493 -0.083906       1.000000      0.132122
# remote_ratio    0.076314 -0.014608       0.132122      1.000000

# %% [markdown]
# - OBJETIVO: Mostrar el proceso realizado por los secuenciadores de acuerdo a lo establecido en su Instrucción de Trabajo en un periodo determinado.

# %% [markdown]
# - Tabla de contenido:
#
# | Dato a Analizar | Descripción |
# | --- | --- |
# | Cliente | Menciona el cliente que está pagando el protecto |
# | Usuario | Lista de los usuarios que realizan el secuenciado |
# | Dia | Se muestra la carga de trabajo por día |
# | Hora | Se muestra la carga de trabajo por hora |
# | Tipo de SLT | Muestra la sección donde está el usuario |

# %% [markdown]
# #LIBRERIAS NUMPY Y PANDAS
#
# - NUMPY
#  Es una biblioteca de computación matemática, mas eficiente y rápida al manipular datos.
#
# - PANDAS: Facilita la manipulación de grandes volúmenes de datos a través de un conjunto de métodos y estructuras diseñadas para tal fin
#
# **FUNCIONALIDAD**
#
# 1.   CARGAR
# 2.   MODELAR
# 3.   ANALIZAR
# 4.   MANIPULAR
# 5.   PREPARAR

# %% [markdown]
# **ÍNDICE**
#
# 1.   Cargar Librerías.
# 2.   Subir Archivo.
# 3.   Leer, mostrar contenido, enlistar los primeros 5 registros.
# 4.   Se obtiene el total de registros y nombre de las columnas.
# 5.   Descripción de las columnas.
# 6.   Obtener el conteo de los registros de la base de datos.
# 7. Se valida si existen datos nulos en el DataFrame.

# %% [markdown]
# # Desarrollo del PROYECTO

# %% [markdown]
# 1. Como primer paso se deben cargar las librerías que se ocuparan en el desarrollo del código.

# %%
#Cargar librerías
import numpy as np
import pandas as pd
import os
import csv
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# 2. Después de cargar las librerías que ocuparemos durante el proyecto, se indicará la ruta de acceso de la base de datos que estaremos analizando.

# %%
#Cargar csv con pd.read_csv

from google.colab import files
archivo = pd.read_csv('/content/ds_salaries.csv')

# %% [markdown]
# 3. Al tener el archivo, se muestra una tabla de contenido de los datos.

# %%
df = pd.read_csv('/content/ds_salaries.csv')
df
# Out:
#      Unnamed: 0  work_year experience_level employment_type  \
# 0             0       2020               MI              FT
# 1             1       2020               SE              FT
# 2             2       2020               SE              FT
# 3             3       2020               MI              FT
# 4             4       2020               SE              FT
# ..          ...        ...              ...             ...
# 602         602       2022               SE              FT
# 603         603       2022               SE              FT
# 604         604       2022               SE              FT
# 605         605       2022               SE              FT
# 606         606       2022               MI              FT
#
#                       job_title  salary salary_currency  salary_in_usd  \
# 0                Data Scientist   70000             EUR          79833
# 1    Machine Learning Scientist  260000             USD         260000
# 2             Big Data Engineer   85000             GBP         109024
# 3          Product Data Analyst   20000             USD          20000
# 4     Machine Learning Engineer  150000             USD         150000
# ..                          ...     ...             ...            ...
# 602               Data Engineer  154000             USD         154000
# 603               Data Engineer  126000             USD         126000
# 604                Data Analyst  129000             USD         129000
# 605                Data Analyst  150000             USD         150000
# 606                AI Scientist  200000             USD         200000
#
#     employee_residence  remote_ratio company_location company_size
# 0                   DE             0               DE            L
# 1                   JP             0               JP            S
# 2                   GB            50               GB            M
# 3                   HN             0               HN            S
# 4                   US            50               US            L
# ..                 ...           ...              ...          ...
# 602                 US           100               US            M
# 603                 US           100               US            M
# 604                 US             0               US            M
# 605                 US           100               US            M
# 606                 IN           100               US            L
#
# [607 rows x 12 columns]

# %%
# Obtener los primeros 5 registros.
print('Primeros 5 registros:\n', df.head(5))
# Out:
# Primeros 5 registros:
#     Unnamed: 0  work_year experience_level employment_type  \
# 0           0       2020               MI              FT
# 1           1       2020               SE              FT
# 2           2       2020               SE              FT
# 3           3       2020               MI              FT
# 4           4       2020               SE              FT
#
#                     job_title  salary salary_currency  salary_in_usd  \
# 0              Data Scientist   70000             EUR          79833
# 1  Machine Learning Scientist  260000             USD         260000
# 2           Big Data Engineer   85000             GBP         109024
# 3        Product Data Analyst   20000             USD          20000
# 4   Machine Learning Engineer  150000             USD         150000
#
#   employee_residence  remote_ratio company_location company_size
# 0                 DE             0               DE            L
# 1                 JP             0               JP            S
# 2                 GB            50               GB            M
# 3                 HN             0               HN            S
# 4                 US            50               US            L

# %%
#Obtener los registros y columns de dataframe
print('Nombres de columnas:\n ', [df.columns])
print('\n')
print('Cantidad de registros en las filas: ', df.index)
# Out:
# Nombres de columnas:
#   [Index(['Unnamed: 0', 'work_year', 'experience_level', 'employment_type',
#        'job_title', 'salary', 'salary_currency', 'salary_in_usd',
#        'employee_residence', 'remote_ratio', 'company_location',
#        'company_size'],
#       dtype='object')]
#
#
# Cantidad de registros en las filas:  RangeIndex(start=0, stop=607, step=1)

# %% [markdown]
# 5.   Descripción de las columnas

# %% [markdown]
# Columna  | Descripción
# -------------------|------------------
# work_year  |  Año de ingreso
# nave      | Ubicación por nave de producción
# area  | Identificación por área del usuario
# job_title     | Detalle del área
# salary  |  Sueldo total antes de impuesto
# salary_currency      | Sueldo promedio por hora
# salary_in_usd | Sueldo en dolares
# employee_id     | Código de residencia del usuario
# remote_zone  | Código remoto de ubicacion
# company_location     | ubicacion de la compañia
# company_size |  Tamaño de la compañía

# %% [markdown]
# 6.   Obtener el conteo de los registros de la base de datos.

# %%
# Obtener el conteo de registros del Dataframe

df.count()
# Out:
# Unnamed: 0            607
# work_year             607
# experience_level      607
# employment_type       607
# job_title             607
# salary                607
# salary_currency       607
# salary_in_usd         607
# employee_residence    607
# remote_ratio          607
# company_location      607
# company_size          607
# dtype: int64

# %% [markdown]
# 7. Se valida si existen datos nulos en el DataFrame

# %%
# Verificar si existen nulos en la base
df.isnull().sum()
# Out:
# Unnamed: 0            0
# work_year             0
# experience_level      0
# employment_type       0
# job_title             0
# salary                0
# salary_currency       0
# salary_in_usd         0
# employee_residence    0
# remote_ratio          0
# company_location      0
# company_size          0
# dtype: int64

# %% [markdown]
# 8. Muestra las frecuencias de diferentes categorías. Este tipo de tabla es particularmente útil para comprender la distribución de valores en un conjunto de datos.

# %%
#Generar una frecuencia de la columna "experience_level"
df.value_counts()
# Out:
# Unnamed: 0  work_year  experience_level  employment_type  job_title                  salary  salary_currency  salary_in_usd  employee_residence  remote_ratio  company_location  company_size
# 0           2020       MI                FT               Data Scientist             70000   EUR              79833          DE                  0             DE                L               1
# 399         2022       SE                FT               Data Scientist             158200  USD              158200         US                  100           US                L               1
# 401         2022       SE                FT               Data Engineer              154600  USD              154600         US                  100           US                L               1
# 402         2022       SE                FT               Data Analyst               115934  USD              115934         US                  0             US                M               1
# 403         2022       SE                FT               Data Analyst               81666   USD              81666          US                  0             US                M               1
#                                                                                                                                                                                                 ..
# 203         2021       SE                FT               Research Scientist         50000   USD              50000          FR                  100           US                S               1
# 204         2021       MI                FT               Data Scientist             160000  USD              160000         US                  100           US                L               1
# 205         2021       MI                FT               Data Scientist             69600   BRL              12901          BR                  0             BR                S               1
# 206         2021       SE                FT               Machine Learning Engineer  200000  USD              200000         US                  100           US                L               1
# 606         2022       MI                FT               AI Scientist               200000  USD              200000         IN                  100           US                L               1
# Name: count, Length: 607, dtype: int64

# %% [markdown]
# 9. Información general de los datos
# - Obtener un describe de dataframe con las columnas como registros.
# - Indica el numero de filas del dataset
# - Muestra el numero de datos No Nulos por columna (valores validos)
# - Tipo de dato de cada columna
# - Tamaño total del dataframe

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 607 entries, 0 to 606
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          607 non-null    int64
#  1   work_year           607 non-null    int64
#  2   experience_level    607 non-null    object
#  3   employment_type     607 non-null    object
#  4   job_title           607 non-null    object
#  5   salary              607 non-null    int64
#  6   salary_currency     607 non-null    object
#  7   salary_in_usd       607 non-null    int64
#  8   employee_residence  607 non-null    object
#  9   remote_ratio        607 non-null    int64
#  10  company_location    607 non-null    object
#  11  company_size        607 non-null    object
# dtypes: int64(5), object(7)
# memory usage: 57.0+ KB

# %% [markdown]
# 10. **MATRIZ DE CORRELACIÓN**
# - La correlación es una técnica estadística que muestra cómo se relacionan dos variables.
# - Se utiliza para encontrar la correlación por pares de todas las columnas en el marco de datos.
# - Cualquier valor na se excluye automáticamente.
# - Para cualquier columna de tipo de datos no numéricos en el marco de datos, se ignora.
#
# Para crear una matriz de correlación usando pandas, se deben seguir estos pasos:
#
# 1. Obtenga los datos.
# 2. Crea el DataFrame.
# 3. Crea una matriz de correlaciones.
# 4. Se genera una gráfica tipo histograma.

# %%
df.describe()
# Out:
#        Unnamed: 0    work_year        salary  salary_in_usd  remote_ratio
# count  607.000000   607.000000  6.070000e+02     607.000000     607.00000
# mean   303.000000  2021.405272  3.240001e+05  112297.869852      70.92257
# std    175.370085     0.692133  1.544357e+06   70957.259411      40.70913
# min      0.000000  2020.000000  4.000000e+03    2859.000000       0.00000
# 25%    151.500000  2021.000000  7.000000e+04   62726.000000      50.00000
# 50%    303.000000  2022.000000  1.150000e+05  101570.000000     100.00000
# 75%    454.500000  2022.000000  1.650000e+05  150000.000000     100.00000
# max    606.000000  2022.000000  3.040000e+07  600000.000000     100.00000

# %%
# Obtener la matriz de correlaciones del dataframe  (Buscar un ejemplo en google)
import seaborn as sb
corr = df.corr()
sb.heatmap(corr, cmap="Blues", annot=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-75-f1721cf84d4b> in <cell line: 3>()
#       1 # Obtener la matriz de correlaciones del dataframe  (Buscar un ejemplo en google)
#       2 import seaborn as sb
# ----> 3 corr = df.corr()
#       4 sb.heatmap(corr, cmap="Blues", annot=True)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in corr(self, method, min_periods, numeric_only)
#   10702         cols = data.columns
#   10703         idx = cols.copy()
# > 10704         mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10705
#   10706         if method == "pearson":
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in to_numpy(self, dtype, copy, na_value)
#    1887         if dtype is not None:
#    1888             dtype = np.dtype(dtype)
# -> 1889         result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1890         if result.dtype is not dtype:
#    1891             result = np.array(result, dtype=dtype, copy=False)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/managers.py in as_array(self, dtype, copy, na_value)
#    1654                 arr.flags.writeable = False
#    1655         else:
# -> 1656             arr = self._interleave(dtype=dtype, na_value=na_value)
#    1657             # The underlying data was copied within _interleave, so no need
#    1658             # to further copy if copy=True or setting na_value
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/managers.py in _interleave(self, dtype, na_value)
#    1713             else:
#    1714                 arr = blk.get_values(dtype)
# -> 1715             result[rl.indexer] = arr
#    1716             itemmask[rl.indexer] = 1
#    1717
#
# ValueError: could not convert string to float: 'MI'

# %%
#Generar una gráfica de barras de la columna "employee_id"
df = pd.read_csv('/content/ds_salaries.csv', index_col='employment_type')
muestra = df[:10].copy()
muestra
# Out:
#                  Unnamed: 0  work_year experience_level  \
# employment_type
# FT                        0       2020               MI
# FT                        1       2020               SE
# FT                        2       2020               SE
# FT                        3       2020               MI
# FT                        4       2020               SE
# FT                        5       2020               EN
# FT                        6       2020               SE
# FT                        7       2020               MI
# FT                        8       2020               MI
# FT                        9       2020               SE
#
#                                   job_title    salary salary_currency  \
# employment_type
# FT                           Data Scientist     70000             EUR
# FT               Machine Learning Scientist    260000             USD
# FT                        Big Data Engineer     85000             GBP
# FT                     Product Data Analyst     20000             USD
# FT                Machine Learning Engineer    150000             USD
# FT                             Data Analyst     72000             USD
# FT                      Lead Data Scientist    190000             USD
# FT                           Data Scientist  11000000             HUF
# FT                    Business Data Analyst    135000             USD
# FT                       Lead Data Engineer    125000             USD
#
#                  salary_in_usd employee_residence  remote_ratio  \
# employment_type
# FT                       79833                 DE             0
# FT                      260000                 JP             0
# FT                      109024                 GB            50
# FT                       20000                 HN             0
# FT                      150000                 US            50
# FT                       72000                 US           100
# FT                      190000                 US           100
# FT                       35735                 HU            50
# FT                      135000                 US           100
# FT                      125000                 NZ            50
#
#                 company_location company_size
# employment_type
# FT                            DE            L
# FT                            JP            S
# FT                            GB            M
# FT                            HN            S
# FT                            US            L
# FT                            US            L
# FT                            US            S
# FT                            HU            L
# FT                            US            L
# FT                            NZ            S

# %%
from matplotlib import pyplot as plt
import seaborn as sns
muestra.groupby('job_title').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
mean_sal_jobtitle = df.groupby('job_title')['salary_in_usd'].mean().round(2).sort_values(ascending = False)
mean_sal_jobtitle
# Out:
# job_title
# Data Analytics Lead                         405000.00
# Principal Data Engineer                     328333.33
# Financial Data Analyst                      275000.00
# Principal Data Scientist                    215242.43
# Director of Data Science                    195074.00
# Data Architect                              177873.91
# Applied Data Scientist                      175655.00
# Analytics Engineer                          175000.00
# Data Specialist                             165000.00
# Head of Data                                160162.60
# Machine Learning Scientist                  158412.50
# Data Science Manager                        158328.50
# Director of Data Engineering                156738.00
# Head of Data Science                        146718.75
# Applied Machine Learning Scientist          142068.75
# Lead Data Engineer                          139724.50
# Data Analytics Manager                      127134.29
# Cloud Data Engineer                         124647.00
# Data Engineering Manager                    123227.20
# Principal Data Analyst                      122500.00
# ML Engineer                                 117504.00
# Machine Learning Manager                    117104.00
# Lead Data Scientist                         115190.00
# Data Engineer                               112725.00
# Research Scientist                          109019.50
# Data Scientist                              108187.83
# Computer Vision Software Engineer           105248.67
# Staff Data Scientist                        105000.00
# Machine Learning Engineer                   104880.15
# Machine Learning Infrastructure Engineer    101145.00
# Big Data Architect                           99703.00
# Data Analyst                                 92893.06
# Lead Data Analyst                            92203.00
# Marketing Data Analyst                       88654.00
# Lead Machine Learning Engineer               87932.00
# Machine Learning Developer                   85860.67
# Head of Machine Learning                     79039.00
# Business Data Analyst                        76691.20
# Data Science Engineer                        75803.33
# BI Data Analyst                              74755.17
# Data Science Consultant                      69420.71
# AI Scientist                                 66135.57
# Data Analytics Engineer                      64799.25
# Finance Data Analyst                         61896.00
# ETL Developer                                54957.00
# Big Data Engineer                            51974.00
# Computer Vision Engineer                     44419.33
# NLP Engineer                                 37236.00
# Product Data Analyst                         13036.00
# 3D Computer Vision Researcher                 5409.00
# Name: salary_in_usd, dtype: float64

# %%
fig = px.bar(mean_sal_jobtitle, x=mean_sal_jobtitle.index, y=mean_sal_jobtitle.values,
             color=mean_sal_jobtitle.index, text=mean_sal_jobtitle.values, title='Salarios por especilidad' )
fig.update_traces(width=0.4)
fig.update_layout(
    xaxis_title="Especialidad",
    yaxis_title="Salario en dolares",
    font = dict(size=17))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="1a66fcda-44ea-4b5a-9353-49c135ccf255" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1a66fcda-44ea-4b5a-9353-49c135ccf255")) {                    Plotly.newPlot(                        "1a66fcda-44ea-4b5a-9353-49c135ccf255",                        [{"alignmentgroup":"True","hovertemplate":"job_title=%{x}\u003cbr\u003ey=%{y}\u003cbr\u003etext=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Data Analytics Lead","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Data Analytics Lead","offsetgroup":"Data Analytics Lead","orientation":"v","showlegend":true,"text":[405000.0],"textposition":"auto","x":["Data Analytics Lead"],"xaxis":"x","y":[405000.0],"yaxis":"y","type":"bar","width":0.4},{"alignmentgroup":"True","hovertemplate":"job_title=%{x}\u003cbr\u003ey=%{y}\u003cbr\u003etext=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Principal Data Engineer","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Principal Data Engineer","offsetgroup":"Principal Data Engineer","orientation":"v","showlegend":true,"text":[328333.33],"textposition":"auto","x":["Principal Data Engineer"],"xaxis":"x","y":[328333.33],"yaxis":"y","type":"bar","width":0.4},{"alignmentgroup":"True","hovertemplate":"job_title=%{x}\u003cbr\u003ey=%{y}\u003cbr\u003etext=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Financial Data Analyst","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Financial Data Analyst","offsetgroup":"Financial Data Analyst","orientation":"v","showlegend":true,"text":[275000.0],"textposition":"auto","x":["Financial Data Analyst"],"xaxis":"x","y":[275000.0],"yaxis":"y","type":"bar","width":0.4},{"alignmentgroup":"True","hovertemplate":"job_title=%{x}\u003cbr\u003ey=%{y}\u003cbr\u003etext=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Principal Data Scientist","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Principal Data Scientist","offsetgroup":"Principal Data Scientist","orientation":"v","showlegend":true,"text":[215242.43],"textposition":"auto","x":["Principal Data Scientist"],"xaxis":"x","y":[215242.43],"yaxis":"y","type":"bar","width":0.4},{"alignmentgroup":"True","hovertemplate":"job_title=%{x}\u003cbr\u003ey=%{y}\u003cbr\u003etext=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Director of Data Science","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Director of Data Science","offsetgroup":"Director of Data Science","orientation":"v","showlegend":true,"text":[195074.0],"textposition":"auto","x":["Director of Data Science"],"xaxis":"x","y":[195074.0],"yaxis":"y","type":"bar","width":0.4},{"alignmentgroup":"True","hovertemplate":"job_title=%{x}\u003cbr\u003ey=%{y}\u003cbr\u003etext=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Data Architect","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Data Architect","offsetgroup":"Data Architect","orientation":"v","showlegend":true,"text":[177873.91],"textposition":"auto","x":["Data Architect"],"xaxis":"x","y":[177873.91],"yaxis":"y","type":"bar","width":0.4},{"alignmentgroup":"True","hovertemplate":"job_title=%{x}\u003cbr\u003ey=%{y}\u003cbr\u003etext=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Applied Data Scientist","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Applied Data Scientist","offsetgroup":"Applied Data Scientist","orientation":"v","showlegend":true,"text":[175655.0],"textposition":"auto","x":["Applied Data Scientist"],"xaxis":"x","y":[175655.0],"yaxis":"y","type":"bar","width":0.4},{"alignmentgroup":"True","hovertemplate":"job_title=%{x}\u003cbr\u003ey=%{y}\u003cbr\u003etext=%{text}\u003c ...

# %%
# Carga de datos
df = pd.read_csv('/content/ds_salaries.csv')

# %%
# Análisis de correlación de Pearson

# Calculamos la matriz de correlación de Pearson
corr_matrix = df.corr(method ='pearson')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-72-5b26a9341ce3> in <cell line: 4>()
#       2
#       3 # Calculamos la matriz de correlación de Pearson
# ----> 4 corr_matrix = df.corr(method ='pearson')
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in corr(self, method, min_periods, numeric_only)
#   10702         cols = data.columns
#   10703         idx = cols.copy()
# > 10704         mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10705
#   10706         if method == "pearson":
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in to_numpy(self, dtype, copy, na_value)
#    1887         if dtype is not None:
#    1888             dtype = np.dtype(dtype)
# -> 1889         result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1890         if result.dtype is not dtype:
#    1891             result = np.array(result, dtype=dtype, copy=False)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/managers.py in as_array(self, dtype, copy, na_value)
#    1654                 arr.flags.writeable = False
#    1655         else:
# -> 1656             arr = self._interleave(dtype=dtype, na_value=na_value)
#    1657             # The underlying data was copied within _interleave, so no need
#    1658             # to further copy if copy=True or setting na_value
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/managers.py in _interleave(self, dtype, na_value)
#    1713             else:
#    1714                 arr = blk.get_values(dtype)
# -> 1715             result[rl.indexer] = arr
#    1716             itemmask[rl.indexer] = 1
#    1717
#
# ValueError: could not convert string to float: 'MI'

# %%
# Imprimimos la matriz de correlación de Pearson
print(corr_matrix)

# %%
corr_matrix

# %%
from matplotlib import pyplot as plt
corr_matrix['Unnamed: 0'].plot(kind='hist', bins=20, title='Unnamed: 0')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
# Gráficos proporcionados por pandas

# Histograma de la variable 'salary_in_usd'
plt.hist(df['salary_in_usd'])
plt.xlabel('Salario en USD')
plt.ylabel('Frecuencia')
plt.title('Histograma de salarios en USD')
plt.show()

# %%
# Diagrama de dispersión entre las variables 'work_year' y 'salary_in_usd'
sns.scatterplot(x='work_year', y='salary_in_usd', data=df)
plt.xlabel('Año de trabajo')
plt.ylabel('Salario en USD')
plt.title('Diagrama de dispersión entre el año de trabajo y el salario en USD')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-45-eb87fe83bd58> in <cell line: 2>()
#       1 # Diagrama de dispersión entre las variables 'work_year' y 'salary_in_usd'
# ----> 2 sns.scatterplot(x='work_year', y='salary_in_usd', data=df)
#       3 plt.xlabel('Año de trabajo')
#       4 plt.ylabel('Salario en USD')
#       5 plt.title('Diagrama de dispersión entre el año de trabajo y el salario en USD')
#
# NameError: name 'df' is not defined

# %%
# Diagrama de caja y bigotes de la variable 'salary_in_usd' por país
sns.boxplot(x='employee_residence', y='salary_in_usd', showmeans=True, data=df)
plt.xlabel('País de residencia')
plt.ylabel('Salario en USD')
plt.title('Diagrama de caja y bigotes de salarios en USD por país')
plt.xticks(rotation=45)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-44-5d50f6b80992> in <cell line: 2>()
#       1 # Diagrama de caja y bigotes de la variable 'salary_in_usd' por país
# ----> 2 sns.boxplot(x='employee_residence', y='salary_in_usd', showmeans=True, data=df)
#       3 plt.xlabel('País de residencia')
#       4 plt.ylabel('Salario en USD')
#       5 plt.title('Diagrama de caja y bigotes de salarios en USD por país')
#
# NameError: name 'df' is not defined

# %%
# Gráfico de correlación

# Creamos un mapa de calor de la matriz de correlación
plt.matshow(corr_matrix, cmap='RdYlGn')
plt.title('Matriz de correlación')
plt.xlabel('Variables')
plt.ylabel('Variables')
plt.show()

# %% [markdown]
# Interpretación de la matriz de correlación
#
# La matriz de correlación muestra la relación lineal entre dos variables. Los valores de correlación se encuentran entre -1 y 1. Un valor de correlación de 1 indica una relación lineal positiva perfecta, un valor de correlación de -1 indica una relación lineal negativa perfecta y un valor de correlación de 0 indica que no hay relación lineal entre las dos variables.
#
# En el caso de este conjunto de datos, la variable salary_in_usd tiene una correlación positiva significativa con las variables work_year y experience_level. Esto significa que a medida que aumenta el número de años de trabajo o el nivel de experiencia, también aumenta el salario.
#
# La variable salary_in_usd también tiene una correlación negativa significativa con la variable remote_ratio. Esto significa que a medida que aumenta la proporción de trabajo remoto, disminuye el salario.
#
# La variable company_size no tiene una correlación significativa con ninguna de las otras variables. Esto significa que el tamaño de la empresa no tiene un impacto significativo en el salario.
#
# Gráfico de correlación con pandas
#
# Para crear un gráfico de correlación con pandas, podemos usar la función matshow(). Esta función crea un mapa de calor de la matriz de correlación.
#
# En el código anterior, creamos un mapa de calor de la matriz de correlación usando la función matshow(). El mapa de calor muestra que la variable salary_in_usd tiene una correlación positiva significativa con las variables work_year y experience_level.

# %% [markdown]
# # <a name="preparacion"></a>  conclucines
# - Después de analizar los datos, se puede determinar las cargas de trabajo por usuario, los salarios de cada uno y con la estadística se pueden hacer proyecciones para los siguientes años.

# %% [markdown]
# # <a name="preparacion"></a>  referencias y Links de Apoyo
# (referencias)
# https://www.codigopiton.com/como-hacer-un-histograma-en-python/
# https://cursosinformatica.ucm.es/trial/dataviz/
# https://datacarpentry.org/python-ecology-lesson-es/08-putting-it-all-together/index.html
# https://es.acervolima.com/como-crear-una-matriz-de-correlacion-usando-pandas/#:~:text=El%20m%C3%A9todo%20de%20Pandas%20dataframe,valor%20na%20se%20excluye%20autom%C3%A1ticamente.
# https://www.analyticslane.com/2020/12/07/pandas-obtener-el-nombre-de-las-columnas-y-filas-en-pandas/
